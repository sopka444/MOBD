# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
df = pd.read_csv('weather_classification_data.csv', sep = ',')

# %%
df.head(10)
# Out:
#    Temperature  Humidity  Wind Speed  Precipitation (%)    Cloud Cover  \
# 0      14.0000        73      9.5000            82.0000  partly cloudy
# 1      39.0000        96      8.5000            71.0000  partly cloudy
# 2      30.0000        64      7.0000            16.0000          clear
# 3      38.0000        83      1.5000            82.0000          clear
# 4      27.0000        74     17.0000            66.0000       overcast
# 5      32.0000        55      3.5000            26.0000       overcast
# 6      -2.0000        97      8.0000            86.0000       overcast
# 7       3.0000        85      6.0000            96.0000  partly cloudy
# 8       3.0000        83      6.0000            66.0000       overcast
# 9      28.0000        74      8.5000           107.0000          clear
#
#    Atmospheric Pressure  UV Index  Season  Visibility (km)  Location  \
# 0             1010.8200         2  Winter           3.5000    inland
# ...

# %% [markdown]
# # Описание данных
# Признаки:
# 	Temperature - температура \
#      Humidity - влажность \
#      Wind Speed - скорость ветра \
#      Precipitation - осадки \
#      Cloud Cover - облачность \
#      Atmospheric Pressure - атмосферное давление \
#      UV Index - ультрафиолетовый индекс \
#      Season - сезон \
#      Visibility - видимость \
#      Location - локация \
#      Weather Type - тип погоды

# %%
df.shape
# Out:
# (13200, 11)

# %%
df.dtypes
# Out:
# Temperature             float64
# Humidity                  int64
# Wind Speed              float64
# Precipitation (%)       float64
# Cloud Cover              object
# Atmospheric Pressure    float64
# UV Index                  int64
# Season                   object
# Visibility (km)         float64
# Location                 object
# Weather Type             object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13200 entries, 0 to 13199
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Temperature           13200 non-null  float64
#  1   Humidity              13200 non-null  int64
#  2   Wind Speed            13200 non-null  float64
#  3   Precipitation (%)     13200 non-null  float64
#  4   Cloud Cover           13200 non-null  object
#  5   Atmospheric Pressure  13200 non-null  float64
#  6   UV Index              13200 non-null  int64
#  7   Season                13200 non-null  object
#  8   Visibility (km)       13200 non-null  float64
#  9   Location              13200 non-null  object
#  10  Weather Type          13200 non-null  object
# dtypes: float64(5), int64(2), object(4)
# memory usage: 1.1+ MB

# %%
df.columns
# Out:
# Index(['Temperature', 'Humidity', 'Wind Speed', 'Precipitation (%)',
#        'Cloud Cover', 'Atmospheric Pressure', 'UV Index', 'Season',
#        'Visibility (km)', 'Location', 'Weather Type'],
#       dtype='object')

# %%
for col in df.columns:
    print('Кол-во пропусков в колонке %s = %d' % (col, df[col].isna().sum()))
# Out:
# Кол-во пропусков в колонке Temperature = 0
# Кол-во пропусков в колонке Humidity = 0
# Кол-во пропусков в колонке Wind Speed = 0
# Кол-во пропусков в колонке Precipitation (%) = 0
# Кол-во пропусков в колонке Cloud Cover = 0
# Кол-во пропусков в колонке Atmospheric Pressure = 0
# Кол-во пропусков в колонке UV Index = 0
# Кол-во пропусков в колонке Season = 0
# Кол-во пропусков в колонке Visibility (km) = 0
# Кол-во пропусков в колонке Location = 0
# Кол-во пропусков в колонке Weather Type = 0

# %%
df.isnull().sum()
# Out:
# Temperature             0
# Humidity                0
# Wind Speed              0
# Precipitation (%)       0
# Cloud Cover             0
# Atmospheric Pressure    0
# UV Index                0
# Season                  0
# Visibility (km)         0
# Location                0
# Weather Type            0
# dtype: int64

# %%
df['Location'].nunique()
# Out:
# 3

# %%
df['Location'].unique()
# Out:
# array(['inland', 'mountain', 'coastal'], dtype=object)

# %%
df['Location'].value_counts(normalize=True)
# Out:
# Location
# inland      0.364848
# mountain    0.364621
# coastal     0.270530
# Name: proportion, dtype: float64

# %%
# статистика по типу погоды
print('кол-во уникальных значений в таргете: ', df['Weather Type'].nunique())
print('перечень уникальных значений в таргете: ', df['Weather Type'].unique())
print('статистика распределения значений в таргете: \n', df['Weather Type'].value_counts(normalize=True))
# Out:
# кол-во уникальных значений в таргете:  4
# перечень уникальных значений в таргете:  ['Rainy' 'Cloudy' 'Sunny' 'Snowy']
# статистика распределения значений в таргете:
#  Weather Type
# Rainy     0.25
# Cloudy    0.25
# Sunny     0.25
# Snowy     0.25
# Name: proportion, dtype: float64

# %%
df['Precipitation (%)'].describe()
# Out:
# count    13200.000000
# mean        53.644394
# std         31.946541
# min          0.000000
# 25%         19.000000
# 50%         58.000000
# 75%         82.000000
# max        109.000000
# Name: Precipitation (%), dtype: float64

# %%
df.describe().T
# Out:
#                         count         mean        std     min    25%      50%  \
# Temperature           13200.0    19.127576  17.386327  -25.00    4.0    21.00
# Humidity              13200.0    68.710833  20.194248   20.00   57.0    70.00
# Wind Speed            13200.0     9.832197   6.908704    0.00    5.0     9.00
# Precipitation (%)     13200.0    53.644394  31.946541    0.00   19.0    58.00
# Atmospheric Pressure  13200.0  1005.827896  37.199589  800.12  994.8  1007.65
# UV Index              13200.0     4.005758   3.856600    0.00    1.0     3.00
# Visibility (km)       13200.0     5.462917   3.371499    0.00    3.0     5.00
#
#                             75%      max
# Temperature             31.0000   109.00
# Humidity                84.0000   109.00
# Wind Speed              13.5000    48.50
# Precipitation (%)       82.0000   109.00
# Atmospheric Pressure  1016.7725  1199.21
# UV Index                 7.0000    14.00
# Visibility (km)          7.5000    20.00

# %% [markdown]
# # Визуальный анализ

# %%
df['Visibility (km)'].value_counts(normalize=False).plot.bar()
# Out:
# <Axes: xlabel='Visibility (km)'>

# %%
df['UV Index'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
df['Visibility (km)'].nunique()
# Out:
# 41

# %%
df['Visibility (km)'].value_counts(normalize=True).plot.barh()
# Out:
# <Axes: ylabel='Visibility (km)'>

# %%
df.hist(figsize=(20,20));

# %%
df['Precipitation (%)'].hist()


plt.title('Гистограмма осадков (%)')
plt.xlabel('Процент осадков')
plt.ylabel('Частота')


plt.show()

# %%
df['Precipitation (%)'].plot.box()
# Out:
# <Axes: >

# %%
df['Precipitation (%)'].plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
sns.violinplot(y=df["Precipitation (%)"], inner="quartile")
# Out:
# <Axes: ylabel='Precipitation (%)'>

# %%
new = ['Temperature',	'Humidity',	'Wind Speed',	'Precipitation (%)',	'Atmospheric Pressure',	'UV Index',	'Season_num','Weather Type']

# %%
df['Season_num'] = df['Season']
d = {'Winter':0, 'Spring':1, 'Summer':2, 'Autumn':3}
df['Season_num'] = df['Season_num'].map(d)

# %%
df['Weather Type']=df['Weather Type'].map({'Rainy':0, 'Cloudy':1, 'Sunny':2, 'Snowy':3})

# %%
df['Weather Type'].unique()
# Out:
# array([0, 1, 2, 3], dtype=int64)

# %%
df.head()
# Out:
#    Temperature  Humidity  Wind Speed  Precipitation (%)    Cloud Cover  \
# 0      14.0000        73      9.5000            82.0000  partly cloudy
# 1      39.0000        96      8.5000            71.0000  partly cloudy
# 2      30.0000        64      7.0000            16.0000          clear
# 3      38.0000        83      1.5000            82.0000          clear
# 4      27.0000        74     17.0000            66.0000       overcast
#
#    Atmospheric Pressure  UV Index  Season  Visibility (km)  Location  \
# 0             1010.8200         2  Winter           3.5000    inland
# 1             1011.4300         7  Spring          10.0000    inland
# 2             1018.7200         5  Spring           5.5000  mountain
# 3             1026.2500         7  Spring           1.0000   coastal
# 4              990.6700         1  Winter           2.5000  mountain
#
#    Weather Type  Season_num
# 0             0           0
# 1             1           1
# 2             2           1
# ...

# %%
corr = df[new].corr()
corr
# Out:
#                       Temperature  Humidity  Wind Speed  Precipitation (%)  \
# Temperature                1.0000   -0.2080     -0.0700            -0.2872
# Humidity                  -0.2080    1.0000      0.4061             0.6386
# Wind Speed                -0.0700    0.4061      1.0000             0.4438
# Precipitation (%)         -0.2872    0.6386      0.4438             1.0000
# Atmospheric Pressure       0.2092   -0.1207     -0.0778            -0.1774
# UV Index                   0.3748   -0.3427     -0.0681            -0.2916
# Season_num                 0.3795   -0.1810     -0.0477            -0.2054
# Weather Type              -0.4074   -0.0819     -0.1721            -0.0554
#
#                       Atmospheric Pressure  UV Index  Season_num  Weather Type
# Temperature                         0.2092    0.3748      0.3795       -0.4074
# Humidity                           -0.1207   -0.3427     -0.1810       -0.0819
# ...

# %%
f,ax = plt.subplots(figsize=(9,6))
sns.heatmap(corr, annot = True, linewidths=1.5 , fmt = '.2f',ax=ax)
# Out:
# <Axes: >

# %%
plt.scatter(df['Temperature'], df['UV Index'])

# %%
sns.scatterplot(data=df, x="Season_num", y="Wind Speed", hue="Humidity")
# Out:
# <Axes: xlabel='Season_num', ylabel='Wind Speed'>

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df[new], alpha=0.05, figsize=(20, 20));

# %% [markdown]
# # Modeling

# %%
Season_cols = pd.get_dummies(df["Season"], dtype=int)

# %%
Season_cols.head()
# Out:
#    Autumn  Spring  Summer  Winter
# 0       0       0       0       1
# 1       0       1       0       0
# 2       0       1       0       0
# 3       0       1       0       0
# 4       0       0       0       1
